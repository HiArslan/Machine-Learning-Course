# %%
import matplotlib.pyplot as plt 
import plotly.express as px 
import pandas as pd

# %%
df = pd.read_csv('National Assembly 2002 - Updated.csv')

# %%
df.isnull().sum()
# Out:
# District                   0
# Seat                       0
# Constituency_title         0
# Candidate_Name             0
# Party                      0
# Votes                      0
# Total_Valid_Votes          0
# Total_Rejected_Votes       0
# Total_Votes                0
# Total_Registered_Voters    0
# Turnout                    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['District', 'Seat', 'Constituency_title', 'Candidate_Name', 'Party',
#        'Votes', 'Total_Valid_Votes', 'Total_Rejected_Votes', 'Total_Votes',
#        'Total_Registered_Voters', 'Turnout'],
#       dtype='object')

# %%
fig = px.line(df , x='Total_Valid_Votes' , y='Total_Rejected_Votes' , color='Party' , title='Total Rejected and Valid Votes of all parties in 2002' ,
     template='plotly_dark')
fig.update_layout(
    hovermode='x unified')
fig.show()
